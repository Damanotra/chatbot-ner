# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install tensorflow-gpu==2.2.0
# !pip install gensim==3.8.3

# %%
import tensorflow as tf
tf.random.set_seed(1)
tf.compat.v1.enable_eager_execution()

import numpy as np
np.random.seed(1)

import gensim
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense, \
    SpatialDropout1D, Bidirectional, Conv1D, concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report, confusion_matrix

# %matplotlib inline

# %%
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
df = pd.read_csv('drive/My Drive/NER/data/data.csv')

# %%
df.head()
# Out:
#           word             tag
# 0     Pengamat               O
# 1      politik               O
# 2         dari               O
# 3  Universitas  B-ORGANIZATION
# 4       Gadjah  I-ORGANIZATION

# %%
sentences = []
cnt = 1

for i in df.itertuples():
    sentences.append(cnt)
    
    if '.' in str(i.word):
        cnt += 1
        
df['sentence #'] = sentences
df.head()
# Out:
#           word             tag  sentence #
# 0     Pengamat               O           1
# 1      politik               O           1
# 2         dari               O           1
# 3  Universitas  B-ORGANIZATION           1
# 4       Gadjah  I-ORGANIZATION           1

# %%
agg_func = lambda s: [(w, t) for w, t in zip(s['word'].values.tolist(), s['tag'].values.tolist())]
grouped = df.groupby('sentence #').apply(agg_func)
sentences = [s for s in grouped]

# %%
words = list(set(df['word'].values))
words.append('PADDING')
num_words = len(words)
tags = list(set(df['tag'].values))
num_tags = len(tags)

# %%
tags = sorted([t for t in tags if t != 'O'], key=lambda x: (x[2], x[0]))
tags.append('O')

# %%
word2idx = {w: i for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
tag2idx
# Out:
# {'B-LOCATION': 0,
#  'B-ORGANIZATION': 4,
#  'B-PERSON': 8,
#  'B-QUANTITY': 12,
#  'B-TIME': 16,
#  'I-LOCATION': 1,
#  'I-ORGANIZATION': 5,
#  'I-PERSON': 9,
#  'I-QUANTITY': 13,
#  'I-TIME': 17,
#  'L-LOCATION': 2,
#  'L-ORGANIZATION': 6,
#  'L-PERSON': 10,
#  'L-QUANTITY': 14,
#  'L-TIME': 18,
#  'O': 20,
#  'U-LOCATION': 3,
#  'U-ORGANIZATION': 7,
#  'U-PERSON': 11,
#  'U-QUANTITY': 15,
#  'U-TIME': 19}

# %% [markdown]
# ### Pad Sequence

# %%
max_len = 20
X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding='post', value=num_words-1)

y = [[tag2idx[w[1]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding='post', value=tag2idx['O'])
y = [to_categorical(i, num_classes=num_tags) for i in y]

# %%
x_train, x_val_test, y_train, y_val_test = train_test_split(X, y, test_size=0.3, random_state=1)
x_val, x_test, y_val, y_test = train_test_split(x_val_test, y_val_test, test_size=0.5, random_state=1)

# %% [markdown]
# ### Pre-trained Word2Vec Embedding

# %%
model = gensim.models.Word2Vec.load("drive/My Drive/NER/checkpoint/w2vec_wiki_id_case")

# %%
embedding_matrix = np.zeros((len(words), 400))

for i, w in enumerate(words):
    try:
        embedding_vector = model.wv[w]
        embedding_matrix[i] = embedding_vector
    except:
        embedding_matrix[i] = np.random.normal(0, np.sqrt(0.25), 400)

# %% [markdown]
# Initial parameters

# %%
params = {
    'optimizer': 'Adam',
    'lr': 0.001,
    'lstm_units': 100,
    'filters': [128],
    'filter_size': [3],
    'dropout': 0.1,
    'batch_size': 128
}

# %%
def get_report(model, history):
    # plot loss
    fig=plt.figure(figsize=(7,5))
    plt.plot(history.history['loss'], "-o")
    plt.plot(history.history['val_loss'], "-o")
    plt.title('loss')
    plt.xlabel('epoch')
    plt.ylim(0,1)
    plt.show();
    
    print()
    # plot f1 score
    fig=plt.figure(figsize=(7,5))
    plt.plot(history.history['f1_score_micro'], "-o")
    plt.plot(history.history['val_f1_score_micro'], "-o")
    plt.title('f1_micro')
    plt.xlabel('epoch')
    plt.ylim(0,1)
    plt.show();
    
    print()
    # f1 score micro average
    actuals = np.argmax(np.array(y_test), axis=-1).reshape(-1)
    preds = model.predict(x_test)
    preds = np.argmax(preds, axis=-1).reshape(-1)

    score = f1_score(actuals, preds, average='micro')

    print('f1 score micro average include label O:', score)
    
    print()
    # print classification report
    print(classification_report(actuals, preds, target_names=tags, ))
    
    print()
    # f1 score micro average
    actuals = np.argmax(np.array(y_test), axis=-1).reshape(-1)
    preds = model.predict(x_test)
    preds = np.argmax(preds, axis=-1).reshape(-1)

    o_pad_idx = np.where(actuals==20)

    actuals = np.delete(actuals, o_pad_idx)
    preds = np.delete(preds, o_pad_idx)

    score = f1_score(actuals, preds, average='micro')

    print('f1 score micro average without label O:', score)
    
    print()
    # plot confusion matrix
    fig, ax = plt.subplots(figsize=(10,10))

    cm_matrix = confusion_matrix(actuals, preds)
    cm_matrix = np.delete(cm_matrix, (20), axis=0)
    cm_matrix = np.delete(cm_matrix, (20), axis=1)

    ax.matshow(cm_matrix, cmap=plt.cm.Blues)

    for i in range(num_tags-1):
        for j in range(num_tags-1):
            c = cm_matrix[j,i]
            ax.text(i, j, str(c), va='center', ha='center')

    plt.xticks(range(num_tags-1),['{} ({})'.format(tags[:-1][i],i) for i in range(num_tags-1)])
    plt.yticks(range(num_tags-1),['{} ({})'.format(tags[:-1][i],i) for i in range(num_tags-1)])
    plt.xticks(rotation=90)
    plt.show();

# %%
def f1_score_micro(y_true, y_pred):
    y_true = np.argmax(y_true.numpy(), axis=-1).reshape(-1)
    y_pred = np.argmax(y_pred.numpy(), axis=-1).reshape(-1)
    
    # label O will be ignored during training and evaluation
    o_pad_idx = np.where(y_true==20) # 20 is the idx for label O
    
    # remove label O
    y_true = np.delete(y_true, o_pad_idx)
    y_pred = np.delete(y_pred, o_pad_idx)
    
    # compute f1 score with with micro average
    score = f1_score(y_true, y_pred, average='micro')
    
    return score

# %%
def create_model(params, w2v=False, cnn=False):
    input_sequence = Input(shape=(max_len, ))
    
    # embedding layer
    if w2v:
        model = Embedding(
            input_dim= embedding_matrix.shape[0], 
            weights=[embedding_matrix], 
            output_dim=embedding_matrix.shape[1], 
            input_length=max_len,
            trainable=False
        )(input_sequence)
    else:
        model = Embedding(
            input_dim=num_words,
            output_dim=400,
            input_length=max_len,
        )(input_sequence)
    
    # dropout layer
    model = SpatialDropout1D(0.1)(model)
    
    # convolution layer
    if cnn:
        if len(params['filters']) == 1:
            model = Conv1D(params['filters'][0], params['filter_size'][0], activation='relu', padding='same')(model)
        else:
            cnns = []
            for i, _ in enumerate(params['filters']):
                cnns.append(Conv1D(
                    params['filters'][i], params['filter_size'][i], 
                    activation='relu', padding='same')(model))
            
            model = concatenate(cnns)
            
    # lstm layer
    model = Bidirectional(LSTM(units=100, return_sequences=True))(model)
    
    # output layer
    output_sequence = Dense(num_tags, activation='softmax')(model)
    
    # model
    model = Model(input_sequence, output_sequence)
    
    # learning algorithm (optimizer)
    if params['optimizer'] == 'Nadam':
        optm = tf.keras.optimizers.Nadam(lr=params['lr'])
        
    if params['optimizer'] == 'Adam':
        optm = tf.keras.optimizers.Adam(lr=params['lr'])
        
    if params['optimizer'] == 'RMSprop':
        optm = tf.keras.optimizers.RMSprop(lr=params['lr'])
    
    loss = tf.keras.losses.CategoricalCrossentropy()

    model.compile(loss=loss, optimizer=optm, metrics=[f1_score_micro], run_eagerly=True)
    
    return model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_f1_score_micro', mode='max')

# %% [markdown]
# ### BiLSTM

# %%
bilstm = create_model(params)

# %%
bilstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 20, 400)           5212400
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 20, 400)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 20, 200)           400800
# _________________________________________________________________
# dense (Dense)                (None, 20, 21)            4221
# =================================================================
# Total params: 5,617,421
# Trainable params: 5,617,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

bilstm_history = bilstm.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 3s 105ms/step - loss: 1.6366 - f1_score_micro: 0.0033 - val_loss: 0.7910 - val_f1_score_micro: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.7418 - f1_score_micro: 0.0000e+00 - val_loss: 0.7034 - val_f1_score_micro: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 3s 108ms/step - loss: 0.6459 - f1_score_micro: 6.5564e-04 - val_loss: 0.6279 - val_f1_score_micro: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.5549 - f1_score_micro: 2.2722e-04 - val_loss: 0.5598 - val_f1_score_micro: 0.0023
# Epoch 5/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.4776 - f1_score_micro: 0.0297 - val_loss: 0.5150 - val_f1_score_micro: 0.0663
# Epoch 6/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.4223 - f1_score_micro: 0.1310 - val_loss: 0.4832 - val_f1_score_micro: 0.1750
# Epoch 7/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.3721 - f1_score_micro: 0.2980 - val_loss: 0.4482 - val_f1_score_micro: 0.2948
# Epoch 8/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.3115 - f1_score_micro: 0.4629 - val_loss: 0.4146 - val_f1_score_micro: 0.3667
# Epoch 9/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.2424 - f1_score_micro: 0.5982 - val_loss: 0.3657 - val_f1_score_micro: 0.4553
# Epoch 10/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.1796 - f1_score_micro: 0.7142 - val_loss: 0.3457 - val_f1_score_micro: 0.4956
# Epoch 11/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.1339 - f1_score_micro: 0.7937 - val_loss: 0.3423 - val_f1_score_micro: 0.5196
# Epoch 12/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.1042 - f1_score_micro: 0.8435 - val_loss: 0.3365 - val_f1_score_micro: 0.5467
# Epoch 13/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0839 - f1_score_micro: 0.8811 - val_loss: 0.3343 - val_f1_score_micro: 0.5631
# Epoch 14/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0705 - f1_score_micro: 0.9048 - val_loss: 0.3387 - val_f1_score_micro: 0.5723
# Epoch 15/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0594 - f1_score_micro: 0.9223 - val_loss: 0.3322 - val_f1_score_micro: 0.6011
# Epoch 16/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0497 - f1_score_micro: 0.9381 - val_loss: 0.3466 - val_f1_score_micro: 0.5734
# Epoch 17/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0414 - f1_score_micro: 0.9514 - val_loss: 0.3456 - val_f1_score_micro: 0.5939
# Epoch 18/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0354 - f1_score_micro: 0.9599 - val_loss: 0.3567 - val_f1_score_micro: 0.5807
# Epoch 19/100
# 27/27 [==============================] - 3s 101ms/step - loss: 0.0302 - f1_score_micro: 0.9668 - val_loss: 0.3593 - val_f1_score_micro: 0.5895
# Epoch 20/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0266 - f1_score_micro: 0.9704 - val_loss: 0.3527 - val_f1_score_micro: 0.6059
# Epoch 21/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0234 - f1_score_micro: 0.9755 - val_loss: 0.3603 - val_f1_score_micro: 0.6036
# Epoch 22/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0208 - f1_score_micro: 0.9788 - val_loss: 0.3820 - val_f1_score_micro: 0.5882
# Epoch 23/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0187 - f1_score_micro: 0.9817 - val_loss: 0.3769 - val_f1_score_micro: 0.5966
# Epoch 24/100
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0166 - f1_score_micro: 0.9834 - val_loss: 0.3741 - val_f1_score_micro: 0.6024
# Epoch 25/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0145 - f1_score_micro: 0.9869 - val_loss: 0.3795 - val_f1_score_micro: 0.6023
# Epoch 26/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0129 - f1_score_micro: 0.9887 - val_loss: 0.3831 - val_f1_score_micro: 0.5992
# Epoch 27/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0119 - f1_score_micro: 0.9902 - val_loss: 0.3947 - val_f1_score_micro: 0.5947
# Epoch 28/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0109 - f1_score_micro: 0.9902 - val_loss: 0.4012 - val_f1_score_micro: 0.5891
# Epoch 29/100
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0097 - f1_score_micro: 0.9920 - val_loss: 0.3974 - val_f1_score_micro: 0.5889
# Epoch 30/100
# 27/27 [==============================] - 3s 100ms/step - loss: 0.0089 - f1_score_micro: 0.9934 - val_loss: 0.4014 - val_f1_score_micro: 0.5944
# CPU times: user 1min 53s, sys: 4.94 s, total: 1min 58s
# Wall time: 1min 33s

# %%
get_report(bilstm, bilstm_history)
# Out:
# f1 score micro average include label O: 0.9267029972752043
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.62      0.53      0.57        83
#     I-LOCATION       0.52      0.32      0.40        68
#     L-LOCATION       0.64      0.62      0.63        86
#     U-LOCATION       0.75      0.71      0.73       189
# B-ORGANIZATION       0.70      0.57      0.63       122
# I-ORGANIZATION       0.64      0.41      0.50       111
# L-ORGANIZATION       0.63      0.55      0.59       128
# U-ORGANIZATION       0.79      0.75      0.77       204
#       B-PERSON       0.84      0.65      0.73       176
#       I-PERSON       0.50      0.36      0.42        50
#       L-PERSON       0.79      0.64      0.70       185
#       U-PERSON       0.83      0.75      0.79       211
#     B-QUANTITY       0.50      0.37      0.42        52
#     I-QUANTITY       0.48      0.26      0.33        43
#     L-QUANTITY       0.40      0.44      0.42        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.67      0.56      0.61        39
#         I-TIME       0.71      0.69      0.70       123
#         L-TIME       0.58      0.44      0.50        41
#         U-TIME       0.58      0.33      0.42        21
#              O       0.95      0.98      0.97     12699
#
#       accuracy                           0.93     14680
#      macro avg       0.63      0.52      0.56     14680
#   weighted avg       0.92      0.93      0.92     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.596668349318526

# %% [markdown]
# ### BiLSTM + w2v

# %%
bilstm_w2v = create_model(params, w2v=True)

# %%
bilstm_w2v.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 20, 400)           5212400
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 20, 400)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 20, 200)           400800
# _________________________________________________________________
# dense_1 (Dense)              (None, 20, 21)            4221
# =================================================================
# Total params: 5,617,421
# Trainable params: 405,021
# Non-trainable params: 5,212,400
# _________________________________________________________________

# %%
# %%time

bilstm_w2v_history = bilstm_w2v.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 33ms/step - loss: 1.2299 - f1_score_micro: 0.0034 - val_loss: 0.7310 - val_f1_score_micro: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7057 - f1_score_micro: 0.0091 - val_loss: 0.6746 - val_f1_score_micro: 0.0190
# Epoch 3/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6496 - f1_score_micro: 0.0191 - val_loss: 0.6287 - val_f1_score_micro: 0.0326
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6039 - f1_score_micro: 0.0313 - val_loss: 0.5892 - val_f1_score_micro: 0.0325
# Epoch 5/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5613 - f1_score_micro: 0.0422 - val_loss: 0.5493 - val_f1_score_micro: 0.0569
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5182 - f1_score_micro: 0.0726 - val_loss: 0.5078 - val_f1_score_micro: 0.0888
# Epoch 7/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4733 - f1_score_micro: 0.1154 - val_loss: 0.4686 - val_f1_score_micro: 0.1379
# Epoch 8/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4323 - f1_score_micro: 0.1782 - val_loss: 0.4407 - val_f1_score_micro: 0.1779
# Epoch 9/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3972 - f1_score_micro: 0.2294 - val_loss: 0.4058 - val_f1_score_micro: 0.2547
# Epoch 10/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3617 - f1_score_micro: 0.2904 - val_loss: 0.3795 - val_f1_score_micro: 0.2925
# Epoch 11/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3348 - f1_score_micro: 0.3461 - val_loss: 0.3578 - val_f1_score_micro: 0.3375
# Epoch 12/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3106 - f1_score_micro: 0.3991 - val_loss: 0.3404 - val_f1_score_micro: 0.3474
# Epoch 13/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2899 - f1_score_micro: 0.4455 - val_loss: 0.3202 - val_f1_score_micro: 0.4166
# Epoch 14/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2710 - f1_score_micro: 0.4817 - val_loss: 0.3067 - val_f1_score_micro: 0.4310
# Epoch 15/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2532 - f1_score_micro: 0.5177 - val_loss: 0.2957 - val_f1_score_micro: 0.4847
# Epoch 16/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2407 - f1_score_micro: 0.5500 - val_loss: 0.2853 - val_f1_score_micro: 0.5100
# Epoch 17/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2284 - f1_score_micro: 0.5674 - val_loss: 0.2768 - val_f1_score_micro: 0.5197
# Epoch 18/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2164 - f1_score_micro: 0.6008 - val_loss: 0.2705 - val_f1_score_micro: 0.4784
# Epoch 19/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2064 - f1_score_micro: 0.6117 - val_loss: 0.2629 - val_f1_score_micro: 0.5333
# Epoch 20/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1977 - f1_score_micro: 0.6397 - val_loss: 0.2591 - val_f1_score_micro: 0.5227
# Epoch 21/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1880 - f1_score_micro: 0.6515 - val_loss: 0.2521 - val_f1_score_micro: 0.5722
# Epoch 22/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1795 - f1_score_micro: 0.6717 - val_loss: 0.2501 - val_f1_score_micro: 0.5946
# Epoch 23/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1705 - f1_score_micro: 0.6855 - val_loss: 0.2467 - val_f1_score_micro: 0.5848
# Epoch 24/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1658 - f1_score_micro: 0.7015 - val_loss: 0.2473 - val_f1_score_micro: 0.6114
# Epoch 25/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1603 - f1_score_micro: 0.7158 - val_loss: 0.2391 - val_f1_score_micro: 0.5918
# Epoch 26/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1517 - f1_score_micro: 0.7281 - val_loss: 0.2415 - val_f1_score_micro: 0.5995
# Epoch 27/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1472 - f1_score_micro: 0.7351 - val_loss: 0.2408 - val_f1_score_micro: 0.5769
# Epoch 28/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1417 - f1_score_micro: 0.7437 - val_loss: 0.2339 - val_f1_score_micro: 0.6199
# Epoch 29/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1347 - f1_score_micro: 0.7579 - val_loss: 0.2338 - val_f1_score_micro: 0.6120
# Epoch 30/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1303 - f1_score_micro: 0.7651 - val_loss: 0.2358 - val_f1_score_micro: 0.6118
# Epoch 31/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1258 - f1_score_micro: 0.7837 - val_loss: 0.2346 - val_f1_score_micro: 0.6175
# Epoch 32/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1252 - f1_score_micro: 0.7777 - val_loss: 0.2373 - val_f1_score_micro: 0.5999
# Epoch 33/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1188 - f1_score_micro: 0.7916 - val_loss: 0.2300 - val_f1_score_micro: 0.6156
# Epoch 34/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1133 - f1_score_micro: 0.8022 - val_loss: 0.2318 - val_f1_score_micro: 0.6165
# Epoch 35/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1092 - f1_score_micro: 0.8123 - val_loss: 0.2347 - val_f1_score_micro: 0.6453
# Epoch 36/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1053 - f1_score_micro: 0.8202 - val_loss: 0.2331 - val_f1_score_micro: 0.6160
# Epoch 37/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1002 - f1_score_micro: 0.8257 - val_loss: 0.2338 - val_f1_score_micro: 0.6360
# Epoch 38/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0978 - f1_score_micro: 0.8311 - val_loss: 0.2359 - val_f1_score_micro: 0.6358
# Epoch 39/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0951 - f1_score_micro: 0.8346 - val_loss: 0.2336 - val_f1_score_micro: 0.6398
# Epoch 40/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0916 - f1_score_micro: 0.8479 - val_loss: 0.2400 - val_f1_score_micro: 0.6010
# Epoch 41/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0872 - f1_score_micro: 0.8536 - val_loss: 0.2366 - val_f1_score_micro: 0.6464
# Epoch 42/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0852 - f1_score_micro: 0.8554 - val_loss: 0.2376 - val_f1_score_micro: 0.6182
# Epoch 43/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0819 - f1_score_micro: 0.8645 - val_loss: 0.2378 - val_f1_score_micro: 0.6249
# Epoch 44/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0794 - f1_score_micro: 0.8709 - val_loss: 0.2415 - val_f1_score_micro: 0.6161
# Epoch 45/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0776 - f1_score_micro: 0.8750 - val_loss: 0.2378 - val_f1_score_micro: 0.6430
# Epoch 46/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0742 - f1_score_micro: 0.8734 - val_loss: 0.2430 - val_f1_score_micro: 0.6500
# Epoch 47/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0722 - f1_score_micro: 0.8813 - val_loss: 0.2404 - val_f1_score_micro: 0.6512
# Epoch 48/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0696 - f1_score_micro: 0.8877 - val_loss: 0.2416 - val_f1_score_micro: 0.6519
# Epoch 49/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0664 - f1_score_micro: 0.8928 - val_loss: 0.2472 - val_f1_score_micro: 0.6372
# Epoch 50/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0658 - f1_score_micro: 0.8952 - val_loss: 0.2435 - val_f1_score_micro: 0.6507
# Epoch 51/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0615 - f1_score_micro: 0.9056 - val_loss: 0.2482 - val_f1_score_micro: 0.6414
# Epoch 52/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0594 - f1_score_micro: 0.9055 - val_loss: 0.2513 - val_f1_score_micro: 0.6510
# Epoch 53/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0590 - f1_score_micro: 0.9070 - val_loss: 0.2593 - val_f1_score_micro: 0.6284
# Epoch 54/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0577 - f1_score_micro: 0.9123 - val_loss: 0.2575 - val_f1_score_micro: 0.6234
# Epoch 55/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0550 - f1_score_micro: 0.9132 - val_loss: 0.2570 - val_f1_score_micro: 0.6376
# Epoch 56/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0524 - f1_score_micro: 0.9204 - val_loss: 0.2525 - val_f1_score_micro: 0.6653
# Epoch 57/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0512 - f1_score_micro: 0.9232 - val_loss: 0.2568 - val_f1_score_micro: 0.6531
# Epoch 58/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0494 - f1_score_micro: 0.9267 - val_loss: 0.2554 - val_f1_score_micro: 0.6638
# Epoch 59/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0486 - f1_score_micro: 0.9242 - val_loss: 0.2576 - val_f1_score_micro: 0.6655
# Epoch 60/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0466 - f1_score_micro: 0.9308 - val_loss: 0.2610 - val_f1_score_micro: 0.6427
# Epoch 61/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0443 - f1_score_micro: 0.9333 - val_loss: 0.2616 - val_f1_score_micro: 0.6569
# Epoch 62/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0434 - f1_score_micro: 0.9397 - val_loss: 0.2610 - val_f1_score_micro: 0.6600
# Epoch 63/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0428 - f1_score_micro: 0.9392 - val_loss: 0.2658 - val_f1_score_micro: 0.6600
# Epoch 64/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0421 - f1_score_micro: 0.9382 - val_loss: 0.2657 - val_f1_score_micro: 0.6477
# Epoch 65/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0390 - f1_score_micro: 0.9467 - val_loss: 0.2663 - val_f1_score_micro: 0.6560
# Epoch 66/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0381 - f1_score_micro: 0.9472 - val_loss: 0.2688 - val_f1_score_micro: 0.6573
# Epoch 67/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0367 - f1_score_micro: 0.9505 - val_loss: 0.2705 - val_f1_score_micro: 0.6676
# Epoch 68/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0358 - f1_score_micro: 0.9524 - val_loss: 0.2749 - val_f1_score_micro: 0.6587
# Epoch 69/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0366 - f1_score_micro: 0.9455 - val_loss: 0.2757 - val_f1_score_micro: 0.6410
# Epoch 70/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0351 - f1_score_micro: 0.9523 - val_loss: 0.2753 - val_f1_score_micro: 0.6595
# Epoch 71/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0337 - f1_score_micro: 0.9575 - val_loss: 0.2721 - val_f1_score_micro: 0.6540
# Epoch 72/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0338 - f1_score_micro: 0.9522 - val_loss: 0.2746 - val_f1_score_micro: 0.6478
# Epoch 73/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0320 - f1_score_micro: 0.9569 - val_loss: 0.2834 - val_f1_score_micro: 0.6338
# Epoch 74/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0316 - f1_score_micro: 0.9593 - val_loss: 0.2821 - val_f1_score_micro: 0.6501
# Epoch 75/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0295 - f1_score_micro: 0.9625 - val_loss: 0.2863 - val_f1_score_micro: 0.6452
# Epoch 76/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0286 - f1_score_micro: 0.9632 - val_loss: 0.2886 - val_f1_score_micro: 0.6462
# Epoch 77/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0286 - f1_score_micro: 0.9652 - val_loss: 0.2868 - val_f1_score_micro: 0.6605
# CPU times: user 1min 10s, sys: 2.55 s, total: 1min 13s
# Wall time: 1min 11s

# %%
get_report(bilstm_w2v, bilstm_w2v_history)
# Out:
# f1 score micro average include label O: 0.9292915531335149
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.62      0.48      0.54        83
#     I-LOCATION       0.55      0.49      0.52        68
#     L-LOCATION       0.68      0.60      0.64        86
#     U-LOCATION       0.71      0.72      0.72       189
# B-ORGANIZATION       0.58      0.52      0.55       122
# I-ORGANIZATION       0.61      0.46      0.53       111
# L-ORGANIZATION       0.56      0.48      0.51       128
# U-ORGANIZATION       0.65      0.64      0.64       204
#       B-PERSON       0.82      0.77      0.79       176
#       I-PERSON       0.53      0.54      0.53        50
#       L-PERSON       0.86      0.78      0.82       185
#       U-PERSON       0.78      0.80      0.79       211
#     B-QUANTITY       0.38      0.31      0.34        52
#     I-QUANTITY       0.63      0.28      0.39        43
#     L-QUANTITY       0.44      0.38      0.40        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.76      0.64      0.69        39
#         I-TIME       0.80      0.76      0.78       123
#         L-TIME       0.71      0.66      0.68        41
#         U-TIME       0.53      0.38      0.44        21
#              O       0.96      0.98      0.97     12699
#
#       accuracy                           0.93     14680
#      macro avg       0.63      0.55      0.58     14680
#   weighted avg       0.93      0.93      0.93     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.6259464916708734

# %% [markdown]
# ### BiLSTM-CNNs

# %%
bilstm_cnns = create_model(params, cnn=True)

# %%
bilstm_cnns.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 20, 400)           5212400
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 20, 400)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 20, 128)           153728
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 20, 200)           183200
# _________________________________________________________________
# dense_2 (Dense)              (None, 20, 21)            4221
# =================================================================
# Total params: 5,553,549
# Trainable params: 5,553,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

bilstm_cnns_history = bilstm_cnns.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 3s 113ms/step - loss: 1.4964 - f1_score_micro: 0.0022 - val_loss: 0.7633 - val_f1_score_micro: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.7309 - f1_score_micro: 0.0000e+00 - val_loss: 0.6927 - val_f1_score_micro: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.6446 - f1_score_micro: 0.0000e+00 - val_loss: 0.6368 - val_f1_score_micro: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.5598 - f1_score_micro: 0.0000e+00 - val_loss: 0.5585 - val_f1_score_micro: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.4549 - f1_score_micro: 0.0494 - val_loss: 0.5008 - val_f1_score_micro: 0.1359
# Epoch 6/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.3676 - f1_score_micro: 0.2700 - val_loss: 0.4522 - val_f1_score_micro: 0.2491
# Epoch 7/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.2844 - f1_score_micro: 0.4209 - val_loss: 0.4185 - val_f1_score_micro: 0.3361
# Epoch 8/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.2114 - f1_score_micro: 0.5769 - val_loss: 0.3916 - val_f1_score_micro: 0.4485
# Epoch 9/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.1524 - f1_score_micro: 0.7341 - val_loss: 0.3844 - val_f1_score_micro: 0.4966
# Epoch 10/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.1067 - f1_score_micro: 0.8393 - val_loss: 0.3790 - val_f1_score_micro: 0.5416
# Epoch 11/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0769 - f1_score_micro: 0.8932 - val_loss: 0.3761 - val_f1_score_micro: 0.5819
# Epoch 12/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0581 - f1_score_micro: 0.9245 - val_loss: 0.3840 - val_f1_score_micro: 0.5870
# Epoch 13/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0445 - f1_score_micro: 0.9432 - val_loss: 0.3940 - val_f1_score_micro: 0.5826
# Epoch 14/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0353 - f1_score_micro: 0.9572 - val_loss: 0.4032 - val_f1_score_micro: 0.5928
# Epoch 15/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0290 - f1_score_micro: 0.9647 - val_loss: 0.4105 - val_f1_score_micro: 0.5999
# Epoch 16/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0251 - f1_score_micro: 0.9701 - val_loss: 0.4167 - val_f1_score_micro: 0.6051
# Epoch 17/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0217 - f1_score_micro: 0.9739 - val_loss: 0.4322 - val_f1_score_micro: 0.5853
# Epoch 18/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0183 - f1_score_micro: 0.9793 - val_loss: 0.4297 - val_f1_score_micro: 0.6109
# Epoch 19/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0165 - f1_score_micro: 0.9808 - val_loss: 0.4431 - val_f1_score_micro: 0.6226
# Epoch 20/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0142 - f1_score_micro: 0.9837 - val_loss: 0.4466 - val_f1_score_micro: 0.6078
# Epoch 21/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0122 - f1_score_micro: 0.9865 - val_loss: 0.4581 - val_f1_score_micro: 0.5892
# Epoch 22/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0105 - f1_score_micro: 0.9882 - val_loss: 0.4646 - val_f1_score_micro: 0.6192
# Epoch 23/100
# 27/27 [==============================] - 3s 108ms/step - loss: 0.0092 - f1_score_micro: 0.9906 - val_loss: 0.4654 - val_f1_score_micro: 0.6103
# Epoch 24/100
# 27/27 [==============================] - 3s 109ms/step - loss: 0.0080 - f1_score_micro: 0.9922 - val_loss: 0.4729 - val_f1_score_micro: 0.6036
# Epoch 25/100
# 27/27 [==============================] - 3s 109ms/step - loss: 0.0072 - f1_score_micro: 0.9932 - val_loss: 0.4838 - val_f1_score_micro: 0.6240
# Epoch 26/100
# 27/27 [==============================] - 3s 108ms/step - loss: 0.0064 - f1_score_micro: 0.9939 - val_loss: 0.4871 - val_f1_score_micro: 0.6013
# Epoch 27/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0057 - f1_score_micro: 0.9952 - val_loss: 0.4920 - val_f1_score_micro: 0.6015
# Epoch 28/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0051 - f1_score_micro: 0.9960 - val_loss: 0.4982 - val_f1_score_micro: 0.6085
# Epoch 29/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0049 - f1_score_micro: 0.9962 - val_loss: 0.4979 - val_f1_score_micro: 0.6026
# Epoch 30/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0044 - f1_score_micro: 0.9962 - val_loss: 0.5047 - val_f1_score_micro: 0.6151
# Epoch 31/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0040 - f1_score_micro: 0.9970 - val_loss: 0.5069 - val_f1_score_micro: 0.6278
# Epoch 32/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0036 - f1_score_micro: 0.9976 - val_loss: 0.5105 - val_f1_score_micro: 0.6064
# Epoch 33/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0034 - f1_score_micro: 0.9975 - val_loss: 0.5151 - val_f1_score_micro: 0.6192
# Epoch 34/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.0031 - f1_score_micro: 0.9977 - val_loss: 0.5223 - val_f1_score_micro: 0.5942
# Epoch 35/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0031 - f1_score_micro: 0.9981 - val_loss: 0.5239 - val_f1_score_micro: 0.6063
# Epoch 36/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0029 - f1_score_micro: 0.9975 - val_loss: 0.5299 - val_f1_score_micro: 0.6152
# Epoch 37/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0025 - f1_score_micro: 0.9986 - val_loss: 0.5303 - val_f1_score_micro: 0.6231
# Epoch 38/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0025 - f1_score_micro: 0.9976 - val_loss: 0.5368 - val_f1_score_micro: 0.6173
# Epoch 39/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0022 - f1_score_micro: 0.9987 - val_loss: 0.5381 - val_f1_score_micro: 0.6076
# Epoch 40/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0020 - f1_score_micro: 0.9987 - val_loss: 0.5390 - val_f1_score_micro: 0.6149
# Epoch 41/100
# 27/27 [==============================] - 3s 104ms/step - loss: 0.0020 - f1_score_micro: 0.9988 - val_loss: 0.5397 - val_f1_score_micro: 0.6059
# CPU times: user 2min 35s, sys: 6.27 s, total: 2min 42s
# Wall time: 2min 1s

# %%
get_report(bilstm_cnns, bilstm_cnns_history)
# Out:
# f1 score micro average include label O: 0.9202316076294278
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.67      0.59      0.63        83
#     I-LOCATION       0.35      0.26      0.30        68
#     L-LOCATION       0.60      0.65      0.62        86
#     U-LOCATION       0.76      0.65      0.70       189
# B-ORGANIZATION       0.73      0.56      0.63       122
# I-ORGANIZATION       0.66      0.50      0.57       111
# L-ORGANIZATION       0.69      0.59      0.64       128
# U-ORGANIZATION       0.75      0.72      0.73       204
#       B-PERSON       0.82      0.63      0.71       176
#       I-PERSON       0.63      0.44      0.52        50
#       L-PERSON       0.81      0.59      0.68       185
#       U-PERSON       0.79      0.73      0.76       211
#     B-QUANTITY       0.30      0.42      0.35        52
#     I-QUANTITY       0.19      0.35      0.24        43
#     L-QUANTITY       0.27      0.52      0.36        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.67      0.62      0.64        39
#         I-TIME       0.76      0.72      0.74       123
#         L-TIME       0.47      0.63      0.54        41
#         U-TIME       0.38      0.48      0.43        21
#              O       0.96      0.97      0.96     12699
#
#       accuracy                           0.92     14680
#      macro avg       0.58      0.55      0.56     14680
#   weighted avg       0.92      0.92      0.92     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.6037354871277133

# %% [markdown]
# ### BiLSTM-CNNs + w2v

# %%
bilstm_cnns_w2v = create_model(params, w2v=True, cnn=True)

# %%
bilstm_cnns_w2v.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 20, 400)           5212400
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 20, 400)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           153728
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 20, 200)           183200
# _________________________________________________________________
# dense_3 (Dense)              (None, 20, 21)            4221
# =================================================================
# Total params: 5,553,549
# Trainable params: 341,149
# Non-trainable params: 5,212,400
# _________________________________________________________________

# %%
# %%time

bilstm_cnns_w2v_history = bilstm_cnns_w2v.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 34ms/step - loss: 1.1441 - f1_score_micro: 0.0016 - val_loss: 0.7669 - val_f1_score_micro: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7104 - f1_score_micro: 1.3517e-04 - val_loss: 0.6651 - val_f1_score_micro: 0.0098
# Epoch 3/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6386 - f1_score_micro: 0.0119 - val_loss: 0.6064 - val_f1_score_micro: 0.0217
# Epoch 4/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5743 - f1_score_micro: 0.0252 - val_loss: 0.5397 - val_f1_score_micro: 0.0450
# Epoch 5/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5070 - f1_score_micro: 0.0716 - val_loss: 0.4789 - val_f1_score_micro: 0.1069
# Epoch 6/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4451 - f1_score_micro: 0.1517 - val_loss: 0.4298 - val_f1_score_micro: 0.1851
# Epoch 7/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.3947 - f1_score_micro: 0.2337 - val_loss: 0.3855 - val_f1_score_micro: 0.2663
# Epoch 8/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3487 - f1_score_micro: 0.3310 - val_loss: 0.3465 - val_f1_score_micro: 0.3337
# Epoch 9/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.3084 - f1_score_micro: 0.4051 - val_loss: 0.3177 - val_f1_score_micro: 0.4166
# Epoch 10/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2833 - f1_score_micro: 0.4640 - val_loss: 0.2985 - val_f1_score_micro: 0.4391
# Epoch 11/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2598 - f1_score_micro: 0.5119 - val_loss: 0.2891 - val_f1_score_micro: 0.5201
# Epoch 12/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2402 - f1_score_micro: 0.5547 - val_loss: 0.2662 - val_f1_score_micro: 0.5096
# Epoch 13/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2211 - f1_score_micro: 0.5970 - val_loss: 0.2567 - val_f1_score_micro: 0.5847
# Epoch 14/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2082 - f1_score_micro: 0.6286 - val_loss: 0.2503 - val_f1_score_micro: 0.5538
# Epoch 15/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1945 - f1_score_micro: 0.6562 - val_loss: 0.2387 - val_f1_score_micro: 0.5912
# Epoch 16/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1828 - f1_score_micro: 0.6793 - val_loss: 0.2325 - val_f1_score_micro: 0.6017
# Epoch 17/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1757 - f1_score_micro: 0.6910 - val_loss: 0.2281 - val_f1_score_micro: 0.6184
# Epoch 18/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1715 - f1_score_micro: 0.7048 - val_loss: 0.2246 - val_f1_score_micro: 0.6386
# Epoch 19/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1612 - f1_score_micro: 0.7210 - val_loss: 0.2253 - val_f1_score_micro: 0.6763
# Epoch 20/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1557 - f1_score_micro: 0.7324 - val_loss: 0.2163 - val_f1_score_micro: 0.6605
# Epoch 21/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1454 - f1_score_micro: 0.7541 - val_loss: 0.2155 - val_f1_score_micro: 0.6268
# Epoch 22/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1425 - f1_score_micro: 0.7531 - val_loss: 0.2119 - val_f1_score_micro: 0.6788
# Epoch 23/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1373 - f1_score_micro: 0.7665 - val_loss: 0.2138 - val_f1_score_micro: 0.6856
# Epoch 24/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1315 - f1_score_micro: 0.7802 - val_loss: 0.2070 - val_f1_score_micro: 0.6783
# Epoch 25/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1273 - f1_score_micro: 0.7814 - val_loss: 0.2115 - val_f1_score_micro: 0.6638
# Epoch 26/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1232 - f1_score_micro: 0.7987 - val_loss: 0.2186 - val_f1_score_micro: 0.6215
# Epoch 27/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1166 - f1_score_micro: 0.8004 - val_loss: 0.2112 - val_f1_score_micro: 0.6772
# Epoch 28/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.1129 - f1_score_micro: 0.8101 - val_loss: 0.2097 - val_f1_score_micro: 0.6988
# Epoch 29/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.1109 - f1_score_micro: 0.8137 - val_loss: 0.2109 - val_f1_score_micro: 0.6692
# Epoch 30/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1065 - f1_score_micro: 0.8159 - val_loss: 0.2109 - val_f1_score_micro: 0.7097
# Epoch 31/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.1007 - f1_score_micro: 0.8340 - val_loss: 0.2134 - val_f1_score_micro: 0.6588
# Epoch 32/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0984 - f1_score_micro: 0.8356 - val_loss: 0.2182 - val_f1_score_micro: 0.6431
# Epoch 33/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0943 - f1_score_micro: 0.8450 - val_loss: 0.2083 - val_f1_score_micro: 0.7067
# Epoch 34/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0906 - f1_score_micro: 0.8504 - val_loss: 0.2161 - val_f1_score_micro: 0.6934
# Epoch 35/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0884 - f1_score_micro: 0.8487 - val_loss: 0.2107 - val_f1_score_micro: 0.7274
# Epoch 36/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0848 - f1_score_micro: 0.8621 - val_loss: 0.2113 - val_f1_score_micro: 0.7122
# Epoch 37/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0802 - f1_score_micro: 0.8694 - val_loss: 0.2149 - val_f1_score_micro: 0.6994
# Epoch 38/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0787 - f1_score_micro: 0.8718 - val_loss: 0.2212 - val_f1_score_micro: 0.6586
# Epoch 39/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0784 - f1_score_micro: 0.8736 - val_loss: 0.2193 - val_f1_score_micro: 0.6835
# Epoch 40/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0754 - f1_score_micro: 0.8712 - val_loss: 0.2173 - val_f1_score_micro: 0.7089
# Epoch 41/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0725 - f1_score_micro: 0.8785 - val_loss: 0.2202 - val_f1_score_micro: 0.7104
# Epoch 42/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0694 - f1_score_micro: 0.8839 - val_loss: 0.2205 - val_f1_score_micro: 0.7079
# Epoch 43/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0652 - f1_score_micro: 0.8934 - val_loss: 0.2168 - val_f1_score_micro: 0.7172
# Epoch 44/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0622 - f1_score_micro: 0.8981 - val_loss: 0.2197 - val_f1_score_micro: 0.7089
# Epoch 45/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0635 - f1_score_micro: 0.8947 - val_loss: 0.2269 - val_f1_score_micro: 0.7053
# CPU times: user 44 s, sys: 1.49 s, total: 45.4 s
# Wall time: 44.2 s

# %%
get_report(bilstm_cnns_w2v, bilstm_cnns_w2v_history)
# Out:
# f1 score micro average include label O: 0.9376021798365123
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.74      0.66      0.70        83
#     I-LOCATION       0.62      0.49      0.55        68
#     L-LOCATION       0.74      0.70      0.72        86
#     U-LOCATION       0.82      0.73      0.77       189
# B-ORGANIZATION       0.64      0.64      0.64       122
# I-ORGANIZATION       0.65      0.57      0.61       111
# L-ORGANIZATION       0.64      0.71      0.67       128
# U-ORGANIZATION       0.70      0.66      0.68       204
#       B-PERSON       0.87      0.86      0.87       176
#       I-PERSON       0.52      0.70      0.60        50
#       L-PERSON       0.88      0.87      0.88       185
#       U-PERSON       0.86      0.79      0.82       211
#     B-QUANTITY       0.51      0.48      0.50        52
#     I-QUANTITY       0.47      0.35      0.40        43
#     L-QUANTITY       0.35      0.46      0.40        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.69      0.56      0.62        39
#         I-TIME       0.83      0.69      0.75       123
#         L-TIME       0.61      0.54      0.57        41
#         U-TIME       0.53      0.38      0.44        21
#              O       0.97      0.98      0.97     12699
#
#       accuracy                           0.94     14680
#      macro avg       0.65      0.61      0.63     14680
#   weighted avg       0.94      0.94      0.94     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.6895507319535588

# %% [markdown]
# ### BiLSTM-CNNs + multi-sequence n-gram

# %%
multi_cnns_params = {
    'optimizer': 'Adam',
    'lr': 0.001,
    'lstm_units': 100,
    'filters': [128, 128, 128, 128, 128],
    'filter_size': [2, 4, 6, 8, 10],
    'dropout': 0.5,
    'batch_size': 128
}

# %%
bilstm_multi_cnns = create_model(multi_cnns_params, cnn=True)

# %%
bilstm_multi_cnns.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 20)]         0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 20, 400)      5212400     input_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 20, 400)      0           embedding_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 20, 128)      102528      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 20, 128)      204928      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 20, 128)      307328      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 20, 128)      409728      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 20, 128)      512128      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 640)      0           conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 20, 200)      592800      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 20, 21)       4221        bidirectional_4[0][0]
# ==================================================================================================
# Total params: 7,346,061
# Trainable params: 7,346,061
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time

bilstm_multi_cnns_history = bilstm_multi_cnns.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=multi_cnns_params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 4s 139ms/step - loss: 1.1487 - f1_score_micro: 0.0019 - val_loss: 0.7475 - val_f1_score_micro: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 3s 112ms/step - loss: 0.6729 - f1_score_micro: 0.0000e+00 - val_loss: 0.6270 - val_f1_score_micro: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5196 - f1_score_micro: 0.0260 - val_loss: 0.4896 - val_f1_score_micro: 0.0794
# Epoch 4/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.3682 - f1_score_micro: 0.2714 - val_loss: 0.4208 - val_f1_score_micro: 0.2948
# Epoch 5/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.2419 - f1_score_micro: 0.5307 - val_loss: 0.3528 - val_f1_score_micro: 0.4345
# Epoch 6/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.1376 - f1_score_micro: 0.7625 - val_loss: 0.3243 - val_f1_score_micro: 0.5572
# Epoch 7/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0754 - f1_score_micro: 0.8914 - val_loss: 0.3235 - val_f1_score_micro: 0.5958
# Epoch 8/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0445 - f1_score_micro: 0.9422 - val_loss: 0.3371 - val_f1_score_micro: 0.5894
# Epoch 9/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0279 - f1_score_micro: 0.9667 - val_loss: 0.3441 - val_f1_score_micro: 0.6086
# Epoch 10/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.0186 - f1_score_micro: 0.9794 - val_loss: 0.3563 - val_f1_score_micro: 0.6162
# Epoch 11/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.0131 - f1_score_micro: 0.9878 - val_loss: 0.3742 - val_f1_score_micro: 0.6001
# Epoch 12/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.0098 - f1_score_micro: 0.9914 - val_loss: 0.3748 - val_f1_score_micro: 0.6364
# Epoch 13/100
# 27/27 [==============================] - 3s 118ms/step - loss: 0.0076 - f1_score_micro: 0.9940 - val_loss: 0.3900 - val_f1_score_micro: 0.6038
# Epoch 14/100
# 27/27 [==============================] - 3s 118ms/step - loss: 0.0058 - f1_score_micro: 0.9956 - val_loss: 0.3975 - val_f1_score_micro: 0.6081
# Epoch 15/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.0048 - f1_score_micro: 0.9965 - val_loss: 0.4048 - val_f1_score_micro: 0.6135
# Epoch 16/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0039 - f1_score_micro: 0.9969 - val_loss: 0.4034 - val_f1_score_micro: 0.6232
# Epoch 17/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0032 - f1_score_micro: 0.9978 - val_loss: 0.4133 - val_f1_score_micro: 0.6145
# Epoch 18/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0027 - f1_score_micro: 0.9985 - val_loss: 0.4143 - val_f1_score_micro: 0.6236
# Epoch 19/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0024 - f1_score_micro: 0.9986 - val_loss: 0.4189 - val_f1_score_micro: 0.6198
# Epoch 20/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0020 - f1_score_micro: 0.9988 - val_loss: 0.4225 - val_f1_score_micro: 0.6253
# Epoch 21/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.0017 - f1_score_micro: 0.9994 - val_loss: 0.4266 - val_f1_score_micro: 0.6264
# Epoch 22/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.0016 - f1_score_micro: 0.9987 - val_loss: 0.4260 - val_f1_score_micro: 0.6312
# CPU times: user 1min 28s, sys: 5.39 s, total: 1min 33s
# Wall time: 1min 12s

# %%
get_report(bilstm_multi_cnns, bilstm_multi_cnns_history)
# Out:
# f1 score micro average include label O: 0.93358310626703
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.66      0.64      0.65        83
#     I-LOCATION       0.53      0.44      0.48        68
#     L-LOCATION       0.72      0.66      0.69        86
#     U-LOCATION       0.79      0.70      0.74       189
# B-ORGANIZATION       0.70      0.62      0.66       122
# I-ORGANIZATION       0.68      0.55      0.61       111
# L-ORGANIZATION       0.71      0.66      0.69       128
# U-ORGANIZATION       0.74      0.76      0.75       204
#       B-PERSON       0.85      0.69      0.76       176
#       I-PERSON       0.71      0.50      0.59        50
#       L-PERSON       0.84      0.65      0.74       185
#       U-PERSON       0.87      0.78      0.82       211
#     B-QUANTITY       0.32      0.40      0.36        52
#     I-QUANTITY       0.60      0.42      0.49        43
#     L-QUANTITY       0.37      0.44      0.40        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.68      0.64      0.66        39
#         I-TIME       0.80      0.75      0.77       123
#         L-TIME       0.62      0.61      0.62        41
#         U-TIME       0.50      0.38      0.43        21
#              O       0.96      0.98      0.97     12699
#
#       accuracy                           0.93     14680
#      macro avg       0.65      0.59      0.61     14680
#   weighted avg       0.93      0.93      0.93     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.6527006562342251

# %% [markdown]
# ### BiLSTM-CNNs + multi-sequence n-gram + w2v

# %%
bilstm_multi_cnns_w2v = create_model(multi_cnns_params, w2v=True, cnn=True)

# %%
bilstm_multi_cnns_w2v.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 20)]         0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 20, 400)      5212400     input_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 20, 400)      0           embedding_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 20, 128)      102528      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 20, 128)      204928      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 20, 128)      307328      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 20, 128)      409728      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 20, 128)      512128      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 640)      0           conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 20, 200)      592800      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 20, 21)       4221        bidirectional_5[0][0]
# ==================================================================================================
# Total params: 7,346,061
# Trainable params: 2,133,661
# Non-trainable params: 5,212,400
# __________________________________________________________________________________________________

# %%
# %%time

bilstm_multi_cnns_w2v_history = bilstm_multi_cnns_w2v.fit(
    x_train, np.array(y_train),
    validation_data=(x_val, np.array(y_val)),
    epochs=100, verbose=1, callbacks=[early_stopping], batch_size=multi_cnns_params['batch_size']
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 43ms/step - loss: 0.9119 - f1_score_micro: 9.1611e-04 - val_loss: 0.6710 - val_f1_score_micro: 0.0130
# Epoch 2/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.6250 - f1_score_micro: 0.0154 - val_loss: 0.5771 - val_f1_score_micro: 0.0360
# Epoch 3/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.5216 - f1_score_micro: 0.0754 - val_loss: 0.4853 - val_f1_score_micro: 0.0946
# Epoch 4/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.4331 - f1_score_micro: 0.1695 - val_loss: 0.4163 - val_f1_score_micro: 0.2498
# Epoch 5/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.3641 - f1_score_micro: 0.2961 - val_loss: 0.3624 - val_f1_score_micro: 0.3335
# Epoch 6/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.3098 - f1_score_micro: 0.4061 - val_loss: 0.3255 - val_f1_score_micro: 0.4194
# Epoch 7/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.2685 - f1_score_micro: 0.4917 - val_loss: 0.2940 - val_f1_score_micro: 0.4857
# Epoch 8/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.2313 - f1_score_micro: 0.5601 - val_loss: 0.2739 - val_f1_score_micro: 0.5529
# Epoch 9/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.2073 - f1_score_micro: 0.6282 - val_loss: 0.2579 - val_f1_score_micro: 0.5545
# Epoch 10/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.1838 - f1_score_micro: 0.6814 - val_loss: 0.2534 - val_f1_score_micro: 0.5375
# Epoch 11/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.1681 - f1_score_micro: 0.7038 - val_loss: 0.2424 - val_f1_score_micro: 0.5739
# Epoch 12/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.1494 - f1_score_micro: 0.7449 - val_loss: 0.2378 - val_f1_score_micro: 0.6000
# Epoch 13/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.1355 - f1_score_micro: 0.7712 - val_loss: 0.2351 - val_f1_score_micro: 0.5976
# Epoch 14/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.1260 - f1_score_micro: 0.7905 - val_loss: 0.2278 - val_f1_score_micro: 0.6281
# Epoch 15/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.1156 - f1_score_micro: 0.8059 - val_loss: 0.2324 - val_f1_score_micro: 0.6261
# Epoch 16/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.1065 - f1_score_micro: 0.8299 - val_loss: 0.2328 - val_f1_score_micro: 0.6078
# Epoch 17/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0980 - f1_score_micro: 0.8412 - val_loss: 0.2248 - val_f1_score_micro: 0.6364
# Epoch 18/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0878 - f1_score_micro: 0.8595 - val_loss: 0.2289 - val_f1_score_micro: 0.6505
# Epoch 19/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0823 - f1_score_micro: 0.8700 - val_loss: 0.2357 - val_f1_score_micro: 0.6054
# Epoch 20/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0725 - f1_score_micro: 0.8850 - val_loss: 0.2343 - val_f1_score_micro: 0.6369
# Epoch 21/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0696 - f1_score_micro: 0.8919 - val_loss: 0.2326 - val_f1_score_micro: 0.6311
# Epoch 22/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0641 - f1_score_micro: 0.8995 - val_loss: 0.2590 - val_f1_score_micro: 0.6127
# Epoch 23/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0644 - f1_score_micro: 0.8964 - val_loss: 0.2450 - val_f1_score_micro: 0.6345
# Epoch 24/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0563 - f1_score_micro: 0.9144 - val_loss: 0.2372 - val_f1_score_micro: 0.6559
# Epoch 25/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0501 - f1_score_micro: 0.9264 - val_loss: 0.2476 - val_f1_score_micro: 0.6498
# Epoch 26/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0483 - f1_score_micro: 0.9248 - val_loss: 0.2593 - val_f1_score_micro: 0.6280
# Epoch 27/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0453 - f1_score_micro: 0.9315 - val_loss: 0.2414 - val_f1_score_micro: 0.6741
# Epoch 28/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0424 - f1_score_micro: 0.9385 - val_loss: 0.2579 - val_f1_score_micro: 0.6586
# Epoch 29/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0380 - f1_score_micro: 0.9449 - val_loss: 0.2539 - val_f1_score_micro: 0.6592
# Epoch 30/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0355 - f1_score_micro: 0.9508 - val_loss: 0.2708 - val_f1_score_micro: 0.6168
# Epoch 31/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0310 - f1_score_micro: 0.9571 - val_loss: 0.2586 - val_f1_score_micro: 0.6743
# Epoch 32/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0304 - f1_score_micro: 0.9570 - val_loss: 0.2707 - val_f1_score_micro: 0.6421
# Epoch 33/100
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0296 - f1_score_micro: 0.9580 - val_loss: 0.2738 - val_f1_score_micro: 0.6372
# Epoch 34/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0293 - f1_score_micro: 0.9568 - val_loss: 0.2730 - val_f1_score_micro: 0.6640
# Epoch 35/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0300 - f1_score_micro: 0.9562 - val_loss: 0.2731 - val_f1_score_micro: 0.6532
# Epoch 36/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.0253 - f1_score_micro: 0.9640 - val_loss: 0.2807 - val_f1_score_micro: 0.6676
# Epoch 37/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0238 - f1_score_micro: 0.9687 - val_loss: 0.2740 - val_f1_score_micro: 0.6426
# Epoch 38/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0202 - f1_score_micro: 0.9745 - val_loss: 0.2831 - val_f1_score_micro: 0.6615
# Epoch 39/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0188 - f1_score_micro: 0.9766 - val_loss: 0.2871 - val_f1_score_micro: 0.6402
# Epoch 40/100
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0173 - f1_score_micro: 0.9795 - val_loss: 0.2848 - val_f1_score_micro: 0.6539
# Epoch 41/100
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0153 - f1_score_micro: 0.9844 - val_loss: 0.2856 - val_f1_score_micro: 0.6666
# CPU times: user 47.1 s, sys: 1.4 s, total: 48.6 s
# Wall time: 47.5 s

# %%
get_report(bilstm_multi_cnns_w2v, bilstm_multi_cnns_w2v_history)
# Out:
# f1 score micro average include label O: 0.932425068119891
#
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.64      0.59      0.61        83
#     I-LOCATION       0.48      0.43      0.45        68
#     L-LOCATION       0.65      0.64      0.65        86
#     U-LOCATION       0.71      0.77      0.74       189
# B-ORGANIZATION       0.63      0.59      0.61       122
# I-ORGANIZATION       0.54      0.44      0.49       111
# L-ORGANIZATION       0.59      0.59      0.59       128
# U-ORGANIZATION       0.69      0.62      0.65       204
#       B-PERSON       0.87      0.83      0.85       176
#       I-PERSON       0.72      0.58      0.64        50
#       L-PERSON       0.86      0.82      0.84       185
#       U-PERSON       0.82      0.75      0.78       211
#     B-QUANTITY       0.53      0.37      0.43        52
#     I-QUANTITY       0.55      0.28      0.37        43
#     L-QUANTITY       0.58      0.40      0.47        48
#     U-QUANTITY       0.00      0.00      0.00         1
#         B-TIME       0.75      0.62      0.68        39
#         I-TIME       0.83      0.73      0.78       123
#         L-TIME       0.70      0.56      0.62        41
#         U-TIME       0.54      0.33      0.41        21
#              O       0.96      0.98      0.97     12699
#
#       accuracy                           0.93     14680
#      macro avg       0.65      0.57      0.60     14680
#   weighted avg       0.93      0.93      0.93     14680
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1 score micro average without label O: 0.6461383139828369
